# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import random
# sphinx_gallery_thumbnail_number = 2

# %%
def display_cells(seqs, cells):
    
#     harvest = np.array([[0.8, 2.4, 2.5, 3.9, 0.0, 4.0, 0.0],
#                         [2.4, 0.0, 4.0, 1.0, 2.7, 0.0, 0.0],
#                         [1.1, 2.4, 0.8, 4.3, 1.9, 4.4, 0.0],
#                         [0.6, 0.0, 0.3, 0.0, 3.1, 0.0, 0.0],
#                         [0.7, 1.7, 0.6, 2.6, 2.2, 6.2, 0.0],
#                         [1.3, 1.2, 0.0, 0.0, 0.0, 3.2, 5.1],
#                         [0.1, 2.0, 0.0, 1.4, 0.0, 1.9, 6.3]])
    fig, ax = plt.subplots()
    
    im = ax.imshow(cells)
    ndim, seq_len = cells.shape 

    # We want to show all ticks...
    ax.set_xticks([])
    ax.set_yticks([])
    # ... and label them with the respective list entries
    ax.set_xticklabels([])
    ax.set_yticklabels([])

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    for i in range(ndim):
        for j in range(seq_len):
            text = ax.text(j, i, seqs[i][j],
                           ha="center", va="center", color="w", fontsize=1)

    # ax.set_title("Harvest of local farmers (in tons/year)")
    fig.dpi = 1000
#     fig.tight_layout()
    plt.show()

# %%
cells = np.loadtxt('tests/cells.txt')

# %%
cells.shape
# Out:
# (47, 100)

# %%
cells = cells.transpose()

# %%
cells.shape
# Out:
# (100, 47)

# %%
seq = '4 / 1 + 8 + 3 / 9 + 9 * 3 * 1 * 5 - 6 / 8 / 8 + 1 / 3 - 9 / 7 / 6 * 2 / 2 * 7 * 7 / 6 * 8 * 7'.split()
seqs = [seq for i in range(cells.shape[0])]

# %%
len(seqs)
# Out:
# 100

# %%
display_cells(seqs, cells)

# %% [markdown]
# # SARNN

# %%
cells = np.loadtxt('tests/sarnn_cells.txt')
cells = cells.transpose()

# %%
seq = '4 / 1 + 8 + 3 / 9 + 9 * 3 * 1 * 5 - 6 / 8 / 8 + 1 / 3 - 9 / 7 / 6 * 2 / 2 * 7 * 7 / 6 * 8 * 7'.split()
seqs = [seq for i in range(cells.shape[0])]

# %%
cells.shape
# Out:
# (100, 47)

# %%
len(seqs[0])
# Out:
# 47

# %%
len(seqs)
# Out:
# 100

# %%
display_cells(seqs, cells)
